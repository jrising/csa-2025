# %% [markdown]
# # Introduction to R

# %% [markdown]
# ## Basic arithmetic

# %%
1 + 3.14159
# Out:
# [1] 4.14159

# %%
pi / 2
# Out:
# [1] 1.570796

# %%
exp(1)
# Out:
# [1] 2.718282

# %% [markdown]
# $e^1$

# %%
exp(1i)
# Out:
# [1] 0.5403023+0.841471i

# %%
exp(1) < pi
# Out:
# [1] TRUE

# %%
"strings"
# Out:
# [1] "strings"

# %% [markdown]
# ## Vectors

# %%
c(1, 2, 3, 4)
# Out:
# [1] 1 2 3 4

# %%
aa = 3

# %%
aa
# Out:
# [1] 3

# %%
xx = c(2, 3, 5, 7)

# %%
xx + 1
# Out:
# [1] 3 4 6 8

# %%
2*xx
# Out:
# [1]  4  6 10 14

# %%
xx^2
# Out:
# [1]  4  9 25 49

# %%
yy = c(1, 2, 3, 4)

# %%
xx * yy
# Out:
# [1]  2  6 15 28

# %%
mean(xx)
# Out:
# [1] 4.25

# %%
xx - 1
# Out:
# [1] 1 2 4 6

# %%
(xx - 1)^2
# Out:
# [1]  1  4 16 36

# %%
sum((xx - 1)^2)
# Out:
# [1] 57

# %%
sum((xx - mean(xx))^2)
# Out:
# [1] 14.75

# %%
sum(abs(xx - 1))
# Out:
# [1] 13

# %%
abs(xx - 3)
# Out:
# [1] 1 0 2 4

# %%
abs(xx - 5)
# Out:
# [1] 3 2 0 2

# %%
xx
# Out:
# [1] 2 3 5 7

# %%
sum(abs(xx - median(xx)))
# Out:
# [1] 7

# %%
xx < 5
# Out:
# [1]  TRUE  TRUE FALSE FALSE

# %%
xx
# Out:
# [1] 2 3 5 7

# %%
xx[1]
# Out:
# [1] 2

# %%
xx[4]
# Out:
# [1] 7

# %%
xx[c(2, 3)]
# Out:
# [1] 3 5

# %%
xx[c(T, T, F, F)]
# Out:
# [1] 2 3

# %%
xx < 5
# Out:
# [1]  TRUE  TRUE FALSE FALSE

# %%
xx[xx < 5]
# Out:
# [1] 2 3

# %% [markdown]
# ## Plotting (1)

# %%
?abs

# %%
?plot

# %%
plot(xx)
# Out:
# plot without title

# %%
plot(c(2, 4, 6, 8), xx)
# Out:
# plot without title

# %%
plot(xx, xx)
# Out:
# plot without title

# %%
plot(xx, xlab="My x-axis", ylab="My y-axis")
# Out:
# plot without title

# %%
plot(xx, type='l')
# Out:
# plot without title

# %%
plot(xx, type='l')
points(xx + .5)
# Out:
# plot without title

# %%
plot(xx, type='l')
points(xx + .5, pch=13, cex=2, col='red')
# Out:
# plot without title

# %%
mms = seq(0, 10, length.out=100)

# %%
mms
# Out:
#   [1]  0.0000000  0.1010101  0.2020202  0.3030303  0.4040404  0.5050505
#   [7]  0.6060606  0.7070707  0.8080808  0.9090909  1.0101010  1.1111111
#  [13]  1.2121212  1.3131313  1.4141414  1.5151515  1.6161616  1.7171717
#  [19]  1.8181818  1.9191919  2.0202020  2.1212121  2.2222222  2.3232323
#  [25]  2.4242424  2.5252525  2.6262626  2.7272727  2.8282828  2.9292929
#  [31]  3.0303030  3.1313131  3.2323232  3.3333333  3.4343434  3.5353535
#  [37]  3.6363636  3.7373737  3.8383838  3.9393939  4.0404040  4.1414141
#  [43]  4.2424242  4.3434343  4.4444444  4.5454545  4.6464646  4.7474747
#  [49]  4.8484848  4.9494949  5.0505051  5.1515152  5.2525253  5.3535354
#  [55]  5.4545455  5.5555556  5.6565657  5.7575758  5.8585859  5.9595960
#  [61]  6.0606061  6.1616162  6.2626263  6.3636364  6.4646465  6.5656566
#  [67]  6.6666667  6.7676768  6.8686869  6.9696970  7.0707071  7.1717172
#  [73]  7.2727273  7.3737374  7.4747475  7.5757576  7.6767677  7.7777778
#  [79]  7.8787879  7.9797980  8.0808081  8.1818182  8.2828283  8.3838384
#  [85]  8.4848485  8.5858586  8.6868687  8.7878788  8.8888889  8.9898990
#  [91]  9.0909091  9.1919192  9.2929293  9.3939394  9.4949495  9.5959596
#  [97]  9.6969697  9.7979798  9.8989899 10.0000000

# %%
xx - mms
# Out:
#   [1]  2.00000000  2.89898990  4.79797980  6.69696970  1.59595960  2.49494949
#   [7]  4.39393939  6.29292929  1.19191919  2.09090909  3.98989899  5.88888889
#  [13]  0.78787879  1.68686869  3.58585859  5.48484848  0.38383838  1.28282828
#  [19]  3.18181818  5.08080808 -0.02020202  0.87878788  2.77777778  4.67676768
#  [25] -0.42424242  0.47474747  2.37373737  4.27272727 -0.82828283  0.07070707
#  [31]  1.96969697  3.86868687 -1.23232323 -0.33333333  1.56565657  3.46464646
#  [37] -1.63636364 -0.73737374  1.16161616  3.06060606 -2.04040404 -1.14141414
#  [43]  0.75757576  2.65656566 -2.44444444 -1.54545455  0.35353535  2.25252525
#  [49] -2.84848485 -1.94949495 -0.05050505  1.84848485 -3.25252525 -2.35353535
#  [55] -0.45454545  1.44444444 -3.65656566 -2.75757576 -0.85858586  1.04040404
#  [61] -4.06060606 -3.16161616 -1.26262626  0.63636364 -4.46464646 -3.56565657
#  [67] -1.66666667  0.23232323 -4.86868687 -3.96969697 -2.07070707 -0.17171717
#  [73] -5.27272727 -4.37373737 -2.47474747 -0.57575758 -5.67676768 -4.77777778
#  [79] -2.87878788 -0.97979798 -6.08080808 -5.18181818 -3.28282828 -1.38383838
#  [85] -6.48484848 -5.58585859 -3.68686869 -1.78787879 -6.88888889 -5.98989899
#  [91] -4.09090909 -2.19191919 -7.29292929 -6.39393939 -4.49494949 -2.59595960
#  [97] -7.69696970 -6.79797980 -4.89898990 -3.00000000

# %%
sum(abs(xx - mms))
# Out:
# [1] 290.2929

# %%
c(1, 2, 3)
# Out:
# [1] 1 2 3

# %%
c(1, c(2, 3))
# Out:
# [1] 1 2 3

# %%
c(c(1, 2), 3)
# Out:
# [1] 1 2 3

# %%
result = c()

# %%
for (mm in mms) {
    value = sum(abs(xx - mm))
    result = c(result, value)
}

# %%
result
# Out:
#   [1] 17.000000 16.595960 16.191919 15.787879 15.383838 14.979798 14.575758
#   [8] 14.171717 13.767677 13.363636 12.959596 12.555556 12.151515 11.747475
#  [15] 11.343434 10.939394 10.535354 10.131313  9.727273  9.323232  8.959596
#  [22]  8.757576  8.555556  8.353535  8.151515  7.949495  7.747475  7.545455
#  [29]  7.343434  7.141414  7.000000  7.000000  7.000000  7.000000  7.000000
#  [36]  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
#  [43]  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
#  [50]  7.000000  7.101010  7.303030  7.505051  7.707071  7.909091  8.111111
#  [57]  8.313131  8.515152  8.717172  8.919192  9.121212  9.323232  9.525253
#  [64]  9.727273  9.929293 10.131313 10.333333 10.535354 10.737374 10.939394
#  [71] 11.282828 11.686869 12.090909 12.494949 12.898990 13.303030 13.707071
#  [78] 14.111111 14.515152 14.919192 15.323232 15.727273 16.131313 16.535354
#  [85] 16.939394 17.343434 17.747475 18.151515 18.555556 18.959596 19.363636
#  [92] 19.767677 20.171717 20.575758 20.979798 21.383838 21.787879 22.191919
#  [99] 22.595960 23.000000

# %%
plot(mms, result)
# Out:
# plot without title

# %%
yy = sapply(seq(0, 10, length.out=100), function(mm) sum(abs(xx - mm)))

# %% [markdown]
# # Air Passenger Data

# %%
data()

# %%
data(AirPassengers)

# %%
?AirPassengers

# %%
AirPassengers
# Out:
#      Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 1949 112 118 132 129 121 135 148 148 136 119 104 118
# 1950 115 126 141 135 125 149 170 170 158 133 114 140
# 1951 145 150 178 163 172 178 199 199 184 162 146 166
# 1952 171 180 193 181 183 218 230 242 209 191 172 194
# 1953 196 196 236 235 229 243 264 272 237 211 180 201
# 1954 204 188 235 227 234 264 302 293 259 229 203 229
# 1955 242 233 267 269 270 315 364 347 312 274 237 278
# 1956 284 277 317 313 318 374 413 405 355 306 271 306
# 1957 315 301 356 348 355 422 465 467 404 347 305 336
# 1958 340 318 362 348 363 435 491 505 404 359 310 337
# 1959 360 342 406 396 420 472 548 559 463 407 362 405
# 1960 417 391 419 461 472 535 622 606 508 461 390 432

# %%
plot(AirPassengers)
# Out:
# plot without title

# %%
hist(diff(AirPassengers))
# Out:
# Plot with title “Histogram of diff(AirPassengers)”

# %%
length(AirPassengers)
# Out:
# [1] 144

# %%
mean(AirPassengers[2:144] / AirPassengers[1:143])
# Out:
# [1] 1.015169

# %%
plot(AirPassengers)
lines(1949:1961, 100 * 1.01516853565818^(12 * (0:12)))
# Out:
# plot without title

# %% [markdown]
# Annual peaks

# %%
AirPassengers
# Out:
#      Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 1949 112 118 132 129 121 135 148 148 136 119 104 118
# 1950 115 126 141 135 125 149 170 170 158 133 114 140
# 1951 145 150 178 163 172 178 199 199 184 162 146 166
# 1952 171 180 193 181 183 218 230 242 209 191 172 194
# 1953 196 196 236 235 229 243 264 272 237 211 180 201
# 1954 204 188 235 227 234 264 302 293 259 229 203 229
# 1955 242 233 267 269 270 315 364 347 312 274 237 278
# 1956 284 277 317 313 318 374 413 405 355 306 271 306
# 1957 315 301 356 348 355 422 465 467 404 347 305 336
# 1958 340 318 362 348 363 435 491 505 404 359 310 337
# 1959 360 342 406 396 420 472 548 559 463 407 362 405
# 1960 417 391 419 461 472 535 622 606 508 461 390 432

# %%
times = time(AirPassengers)

# %%
annmax = c()
annmin = c()
for (year in 1949:1960) {
    maxval = max(AirPassengers[time(AirPassengers) >= year & time(AirPassengers) < year + 1])
    annmax = c(annmax, maxval)
    minval = min(AirPassengers[time(AirPassengers) >= year & time(AirPassengers) < year + 1])
    annmin = c(annmin, minval)
}

# %%
annmax
# Out:
#  [1] 148 170 199 242 272 302 364 413 467 505 559 622

# %%
annmin
# Out:
#  [1] 104 114 145 171 180 188 233 271 301 310 342 390

# %%
length(annmax)
# Out:
# [1] 12

# %%
mean(annmax[2:12] / annmax[1:11])
# Out:
# [1] 1.140113

# %%
mean(annmin[2:12] / annmin[1:11])
# Out:
# [1] 1.1301

# %%
plot(AirPassengers)
lines(1949:1961, 148 * 1.1401131585382^(0:12))
lines(1949:1961, 104 * 1.1300999993363^(0:12))
# Out:
# plot without title

# %%
plot(1949:2025, 148 * 1.1401131585382^(0:76))
lines(1949:2025, 104 * 1.1300999993363^(0:76))
# Out:
# plot without title

# %%
plot(log(AirPassengers))

# %%
df = data.frame(month=time(AirPassengers), pass=AirPassengers)

# %%
head(df)

# %%
summary(lm(log(pass) ~ month, data=df))

# %%
df$pass1 = c(NA, df$pass[1:(nrow(df)-1)])

# %%
df$pass2 = c(NA, NA, df$pass[1:(nrow(df)-2)])

# %%
summary(lm(log(pass) ~ month + log(pass1) + log(pass2), data=df))

# %%
mod = lm(log(pass) ~ month + log(pass1) + log(pass2), data=df)
df$pred = predict(mod, df)

# %%
plot(AirPassengers)
points(time(AirPassengers), exp(df$pred))

# %% [markdown]
# ## Data frames

# %%
df = data.frame(toc=c(3, 5, 7), salinity=c(5, 6, 7))

# %%
write.csv(df, "myfile.csv")

# %%
read.csv("myfile.csv")

# %%
df$toc

# %%
df$toc == c(3, 5, 7)

# %%
df$toc[3]

# %%
df$salinity[df$toc < 7]

# %% [markdown]
# ## Plotting (2)

# %%
install.packages("tidyverse")

# %%
library(tidyverse)

# %% [markdown]
# We're going to use a lot of `ggplot2`.
#
# https://nyu-cdsc.github.io/learningr/assets/data-visualization-2.1.pdf

# %%
df

# %%
ggplot(df, aes(x=toc, y=salinity)) + geom_point() + geom_line() + geom_col() +
  xlab("My great x-axis") + theme_bw()

# %% [markdown]
# # Discoveries data

# %%
data(discoveries)

# %%
?discoveries

# %%
discoveries

# %%
plot(discoveries)

# %%
df = data.frame(year=1860:1959, count=discoveries)

# %%
df

# %%
mean(df$count)

# %%
mean(diff(df$count))

# %%
plot(df$count[2:nrow(df)] * df$count[1:nrow(df)-1])

# %%
hist(df$count)

# %%
hist(diff(df$count))

# %%
hist(log(df$count))

# %%
hist(diff(log(df$count)), 30)

# %%
ggplot(df, aes(year, count)) + geom_point()

# %%
?geom_smooth

# %%
ggplot(df, aes(year, count)) + geom_point() + geom_smooth()

# %%
sumdf = data.frame(count=mean(df$count))

# %%
ggplot(df, aes(year, count)) + geom_point() + geom_hline(data=sumdf, aes(yintercept=count))

# %% [markdown]
# But actually seems to change. Let's do decadal averages!

# %%
seq(1860, 1959, by=10)

# %%
df$year >= 1860 & df$year < 1870

# %%
df$count[df$year >= 1860 & df$year < 1870]

# %%
sumdf = data.frame()
for (decade in seq(1860, 1959, by=10)) {
    mu = mean(df$count[df$year >= decade & df$year < decade + 10])
    sumdf = rbind(sumdf, data.frame(decade=decade, count=mu))
}

# %%
ggplot(df, aes(year, count)) + geom_point() + geom_col(data=sumdf, aes(x=decade + 5, count), alpha=.5)

# %% [markdown]
# Rolling 10-year windows

# %%
sumdf = data.frame()
for (year1 in 1860:1950) {
    mu = mean(df$count[df$year >= year1 & df$year < year1 + 10])
    sumdf = rbind(sumdf, data.frame(year1=year1, count=mu))
}

# %%
head(sumdf)

# %%
ggplot(df, aes(year, count)) + geom_point() + geom_line(data=sumdf, aes(x=year1 + 5, count))

# %%
sumdf = data.frame()
for (year1 in 1860:1940) {
    mu = mean(df$count[df$year >= year1 & df$year < year1 + 20])
    sumdf = rbind(sumdf, data.frame(year1=year1, count=mu))
}

# %%
sumdf2 = data.frame()
for (year1 in 1860:1940) {
    mu = median(df$count[df$year >= year1 & df$year < year1 + 20])
    sumdf2 = rbind(sumdf2, data.frame(year1=year1, count=mu))
}

# %%
ggplot(df, aes(year, count)) + geom_point() + geom_line(data=sumdf, aes(x=year1 + 10, count)) +
  geom_line(data=sumdf2, aes(x=year1 + 5, count))
